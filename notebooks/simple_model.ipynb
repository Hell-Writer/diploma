# %%
import mesa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.append('C:\\Users\\gorbe\\OneDrive\\Рабочий стол\\Учёба ВШЭ\\Диплом')
from custom_module.simple_market_model.world import WorldModel

# %%
model = WorldModel(100)
for _ in range(200):
    model.step()

# %%
model.datacollector.get_model_vars_dataframe()
plt.plot(model.datacollector.get_model_vars_dataframe()[['price', 'demand', 'reserve', 'produce']])
plt.legend(['price', 'demand', 'reserve', 'produce'])
