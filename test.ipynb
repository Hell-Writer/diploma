# %%
from matplotlib import pyplot as plt
import numpy as np
import custom_module

# %%
all_data = [[2.6,3.2,3.6,3.8,3.5,3.5],
[2.7,2.7,2.7,3.0,3.1,4.0],
[2.1,2.1,2.3,2.9,3.1,3.3],
[2.0,2.1,2.3,2.7,2.8,2.9],
[2.7,3.0,3.0,3.7,4.1,4.5],
[1.9,2.0,2.1,3.0,3.0,3.3],
[2.6,2.8,3.0,3.5,3.5,4.0],
[3.4,3.7,4.1,4.8,4.9,4.7],
[2.1,2.1,2.3,2.8,3.0,3.2],
[2.4,2.7,2.9,3.2,3.3,3.5],
[2.3,2.6,2.7,3.2,3.3,3.6],
[2.4,2.4,2.4,2.7,3.0,3.0],
[2.4,2.5,2.4,2.5,2.7,3.2],
[3.9,4.1,4.5,4.9,5.0,4.9],
[2.3,2.4,2.4,2.8,3.4,3.5],
[2.7,2.8,2.9,3.3,3.3,3.1],
[2.3,2.3,2.1,2.4,2.7,3.6]]

# %%
russia = [2.4, 2.6, 2.7, 3.0, 3.3, 3.5]
moscow = [3.4, 3.7, 4.1, 4.8, 4.9, 4.7]
years = [2018, 2019, 2020, 2021, 2022, 2023]
plt.plot(years, russia, label='Median')
plt.plot(years, moscow, label='Moscow')
plt.plot(years, np.array(all_data).T, alpha=0.1)
plt.title('Housing affordability index (HAI) in Russian aglomerations')
plt.xlabel('year')
plt.ylabel('HAI')
plt.legend();

# %%
sum((20720,
6556,
2121,
2357,
2204,
1646,
1696,
2466,
2853,
1359,
1419,
1327,
1366,
1347,
1435,
2130,
1572,))
# Out:
# 54574
